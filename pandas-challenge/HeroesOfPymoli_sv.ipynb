# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data_df= pd.read_csv(file_to_load)
purchase_data_df.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Check for null values and column types
purchase_data_df.info()
purchase_data_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Purchase ID  780 non-null    int64
#  1   SN           780 non-null    object
#  2   Age          780 non-null    int64
#  3   Gender       780 non-null    object
#  4   Item ID      780 non-null    int64
#  5   Item Name    780 non-null    object
#  6   Price        780 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 42.8+ KB
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# ...

# %%
purchase_data_df['Gender'] = purchase_data_df['Gender'].replace(
    {'Other / Non-Disclosed': 'Other'})

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#Find unique players
player_count= len(purchase_data_df["SN"].unique())
player_count

#Create summary dataframe
total_player_df = pd.DataFrame({"Total Players": [player_count]})
total_player_df
# Out:
#    Total Players
# 0            576

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Calculate unique number of items
unique_id = len(purchase_data_df["Item ID"].unique())

#Calculate average price
average_price = purchase_data_df["Price"].mean()


#Calculate number of purchases
total_purchases = purchase_data_df["Purchase ID"].count()

#Calculate total revenue
total_revenue = purchase_data_df["Price"].sum()

# %%
#Create summary dataframe
summary_df = pd.DataFrame({"Number of Unique Items": [unique_id],
                              "Average Price": average_price,
                              "Total Purchases": total_purchases,
                              "Total Revenue": total_revenue})
format_mapping = ({"Average Price": "${:,.2f}",
                   "Total Revenue": "${:,.2f}"})


summary_df.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_8d021_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Number of Unique Items</th>        <th class="col_heading level0 col1" >Average Price</th>        <th class="col_heading level0 col2" >Total Purchases</th>        <th class="col_heading level0 col3" >Total Revenue</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8d021_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8d021_row0_col0" class="data row0 col0" >179</td>
#                         <td id="T_8d021_row0_col1" class="data row0 col1" >$3.05</td>
#                         <td id="T_8d021_row0_col2" class="data row0 col2" >780</td>
#                         <td id="T_8d021_row0_col3" class="data row0 col3" >$2,379.77</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
#Calculate total in gender groups
gender_groups_df = purchase_data_df.groupby("Gender")

#Find unique values
total_count_gender = gender_groups_df.nunique()["SN"]

print(total_count_gender)

#Calculate percentage
gender_percentage = total_count_gender / player_count

# #Create summary dataframe
gender_stats_df = pd.DataFrame({"Total Count": total_count_gender,
                             "Percentage of Players": gender_percentage})

format_mapping = ({"Percentage of Players": "{:,.2%}"})

gender_stats_df.style.format(format_mapping)
# Out:
# Gender
# Female     81
# Male      484
# Other      11
# Name: SN, dtype: int64
# <style  type="text/css" >
# </style><table id="T_7881e_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7881e_level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_7881e_row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_7881e_row0_col1" class="data row0 col1" >14.06%</td>
#             </tr>
#             <tr>
#                         <th id="T_7881e_level0_row1" class="row_heading level0 row1" >Male</th>
# ...

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Calculate purchase count by gender
purchase_count = gender_groups_df["Purchase ID"].count()

#Calculate  average purchase price by gender
purchase_average = gender_groups_df["Price"].mean()

#Calcualte total purchase price by gender
purchase_total= gender_groups_df["Price"].sum()

#Calculate average total purchase price by gender
purchase_totave = purchase_total/purchase_count

# #Create summary datafram
gender_stats_df = pd.DataFrame({"Purchase Count": purchase_count,
                             "Average Purchase Price": purchase_average,
                             "Total Purchase Value": purchase_total,
                             "Avg Total Purchase per Person": purchase_totave})

format_mapping = ({"Average Purchase Price": "${:,.2f}",
                   "Total Purchase Value": "${:,.2f}",
                  "Avg Total Purchase per Person" : "${:,.2f}"})


gender_stats_df.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_9e052_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Gender</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9e052_level0_row0" class="row_heading level0 row0" >Female</th>
#                         <td id="T_9e052_row0_col0" class="data row0 col0" >113</td>
#                         <td id="T_9e052_row0_col1" class="data row0 col1" >$3.20</td>
# ...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Create the bins in which Data will be held
bins = [0, 9.9, 14.9, 19.9, 24.9, 29.9, 34.9, 39.9, 150]

# Create bin names
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34" , "35-39", "40+"]

purchase_data["Age Summary"] = pd.cut(purchase_data["Age"], bins, labels=group_names, include_lowest=True)
purchase_data

#Group by age
age_groups = purchase_data.groupby("Age Summary")

#Count of age groups
count_by_age =age_groups.nunique()["SN"]

#Percentage of age groups
age_percent = count_by_age/player_count

#Create summary dataframe
demo_stats = pd.DataFrame({"Total Count": count_by_age,
                           "Percentage of Players": age_percent})

format_mapping = ({"Percentage of Players": "{:,.2%}"})


demo_stats.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_1996b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total Count</th>        <th class="col_heading level0 col1" >Percentage of Players</th>    </tr>    <tr>        <th class="index_name level0" >Age Summary</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1996b_level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_1996b_row0_col0" class="data row0 col0" >17</td>
#                         <td id="T_1996b_row0_col1" class="data row0 col1" >2.95%</td>
#             </tr>
#             <tr>
#                         <th id="T_1996b_level0_row1" class="row_heading level0 row1" >10-14</th>
#                         <td id="T_1996b_row1_col0" class="data row1 col0" >22</td>
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Purchase count by age
age_purchase = age_groups["Purchase ID"].count()

#Average purchase price by age
avg_purchase_age = age_groups["Price"].mean()

#Total purchase price by age
total_purchase_age = age_groups["Price"].sum()

#Average total purchase per person by age
avg_per_age= total_purchase_age/count_by_age


#Create summary dataframe
age_stats = pd.DataFrame({"Purchase Count": age_purchase,
                             "Average Purchase Price": avg_purchase_age,
                             "Total Purchase Value": total_purchase_age,
                             "Avg Total Purchase per Person": avg_per_age})

format_mapping = ({"Average Purchase Price": "${:,.2f}",
                   "Total Purchase Value": "${:,.2f}",
                  "Avg Total Purchase per Person" : "${:,.2f}"})

age_stats.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_ebda6_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>        <th class="col_heading level0 col3" >Avg Total Purchase per Person</th>    </tr>    <tr>        <th class="index_name level0" >Age Summary</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ebda6_level0_row0" class="row_heading level0 row0" ><10</th>
#                         <td id="T_ebda6_row0_col0" class="data row0 col0" >23</td>
#                         <td id="T_ebda6_row0_col1" class="data row0 col1" >$3.35</td>
# ...

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
#
# * Display a preview of the summary data frame

# %%
#Find all unique users
spender_group_df= purchase_data.groupby("SN")

#Find purchase count by user
count_by_sn = spender_group_df["Purchase ID"].count()

#Find total purchase value by user
total_purch_sn = spender_group_df["Price"].sum()

#Find average purchase value by user
avg_total_sn = total_purch_sn/count_by_sn

#Create summary dataframe
spender_stats_df= pd.DataFrame({"Purchase Count": count_by_sn,
                             "Average Purchase Price": avg_total_sn,
                             "Total Purchase Value": total_purch_sn})

top_spender_df= spender_stats_df.sort_values ("Total Purchase Value", ascending=False)
top_spender_df.head()


format_mapping = ({"Average Purchase Price": "${:,.2f}",
                   "Total Purchase Value": "${:,.2f}",
                  "Avg Total Purchase per Person" : "${:,.2f}"})

top_spender_df.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_866da_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Average Purchase Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >SN</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_866da_level0_row0" class="row_heading level0 row0" >Lisosia93</th>
#                         <td id="T_866da_row0_col0" class="data row0 col0" >5</td>
#                         <td id="T_866da_row0_col1" class="data row0 col1" >$3.79</td>
#                         <td id="T_866da_row0_col2" class="data row0 col2" >$18.96</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#Retrieve the Item ID, Item Name, and Item Price columns
items_df = purchase_data_df[["Item ID", "Item Name", "Price" ]]

#Group by Item ID and Item Name
grouped_items_df= items_df.groupby(["Item ID", "Item Name"])
                                  
#Find all purchase count of items
item_count= grouped_items_df["Price"].count()

#Find total purchase value of items
item_total =grouped_items_df["Price"].sum()
    
#Find item by price
item_price = item_total/item_count

#Create summary dataframe
popular_item_df= pd.DataFrame({"Purchase Count": item_count,
                               "Item Price": item_price,
                               "Total Purchase Value": item_total})
    
most_popular_df = popular_item_df.sort_values("Purchase Count", ascending=False)
most_popular_df.head()


format_mapping = ({"Item Price": "${:,.2f}",
                   "Total Purchase Value": "${:,.2f}"})

most_popular_df.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_94038_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_94038_level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_94038_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_94038_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_94038_row0_col1" class="data row0 col1" >$4.61</td>
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#Sort the above table by total purchase value in descending order
most_profitable_df = popular_item_df.sort_values("Total Purchase Value", ascending=False)
most_profitable_df.head()

format_mapping = ({"Item Price": "${:,.2f}",
                   "Total Purchase Value": "${:,.2f}"})

most_profitable_df.style.format(format_mapping)
# Out:
# <style  type="text/css" >
# </style><table id="T_eecca_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Purchase Count</th>        <th class="col_heading level0 col1" >Item Price</th>        <th class="col_heading level0 col2" >Total Purchase Value</th>    </tr>    <tr>        <th class="index_name level0" >Item ID</th>        <th class="index_name level1" >Item Name</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_eecca_level0_row0" class="row_heading level0 row0" >92</th>
#                         <th id="T_eecca_level1_row0" class="row_heading level1 row0" >Final Critic</th>
#                         <td id="T_eecca_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_eecca_row0_col1" class="data row0 col1" >$4.61</td>
# ...

# %% [markdown]
# ## Observable Trends

# %% [markdown]
# * Male users makes up the majority of the gamers and they also spend more money as opposed to "female" and "other" gamers.
# * Users between the age of 20-24 are most likely to spend more money versus other age groups. We can assume that these users either spend more time playing the game and/or have higher amounts of disposable income.
# * Final Critic is the most popular and most profitable item. This can lead to valuable insights when it comes to creating other options to buy within the game.
